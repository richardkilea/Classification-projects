# %% [markdown]
# ## Problem statement
# We are given a license dataset which holds various information related the business license , The objective of the problem is to predict license Status for the given business.

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# models for classification
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

## Model evaluators
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# load data set
df = pd.read_csv('/content/License_Data.csv')
# Out:
# <ipython-input-24-3dfa344614bd>:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/License_Data.csv')

# %% [markdown]
# # EXLORATORY DATA ANALYSIS

# %%
df.head()
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    35342-20020816     1256593           32811            1
# 1  1358463-20051116     1639294          262311           29
# 2  1980233-20090722     1980233          345008            1
# 3  1476582-20040211     1476582          273121            1
# 4  1141408-20080516     1896750          213785            1
#
#                      LEGAL NAME        DOING BUSINESS AS NAME  \
# 0                  CARMEN CAHUE         CLAUDIA'S BRIDAL SHOP
# 1           ISLA TROPICAL, INC.                 ISLA TROPICAL
# 2                DJS REMODELING          DJS REMODELING, INC.
# 3      ALL-BRY CONSTRUCTION CO.      ALL-BRY CONSTRUCTION CO.
# 4  MCDONOUGH MECHANICAL SERVICE  MCDONOUGH MECHANICAL SERVICE
#
#                       ADDRESS      CITY STATE ZIP CODE  ...  \
# 0  2625 S CENTRAL PARK AVE  1   CHICAGO    IL  60623.0  ...
# 1         2825 W MONTROSE AVE   CHICAGO    IL    60618  ...
# 2           1605  CLAVEY RD 1  HIGHLAND    IL    60035  ...
# 3              8  NORTH TRAIL    LEMONT    IL    60439  ...
# 4             4081  JOSEPH DR  WAUKEGAN    IL    60087  ...
#
#    LICENSE TERM START DATE  LICENSE TERM EXPIRATION DATE  \
# 0      2002-08-16T00:00:00           2003-08-15T00:00:00
# 1      2005-11-16T00:00:00           2006-11-15T00:00:00
# 2      2009-07-22T00:00:00           2011-07-15T00:00:00
# 3      2004-02-11T00:00:00           2005-02-15T00:00:00
# 4      2008-05-16T00:00:00           2010-05-15T00:00:00
#
#   LICENSE APPROVED FOR ISSUANCE          DATE ISSUED  \
# 0           2002-08-21T00:00:00  2006-04-11T00:00:00
# 1           2006-04-05T00:00:00  2006-06-12T00:00:00
# 2           2009-07-22T00:00:00  2009-07-22T00:00:00
# 3           2004-02-10T00:00:00  2004-02-11T00:00:00
# 4           2008-06-04T00:00:00  2008-06-05T00:00:00
#
#    LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 0                         NaN  25.0  41.843613 -87.714618
# 1         2006-06-15T00:00:00  60.0  41.961132 -87.699626
# 2                         NaN   NaN        NaN        NaN
# 3                         NaN   NaN        NaN        NaN
# 4                         NaN   NaN        NaN        NaN
#
#                                             LOCATION LICENSE STATUS
# 0  {'latitude': '41.843612879431845', 'longitude'...            AAI
# 1  {'latitude': '41.96113244107215', 'longitude':...            AAC
# 2                                                NaN            AAI
# 3                                                NaN            AAI
# 4                                                NaN            AAI
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85895 entries, 0 to 85894
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 85895 non-null  object
#  1   LICENSE ID                         85895 non-null  int64
#  2   ACCOUNT NUMBER                     85895 non-null  int64
#  3   SITE NUMBER                        85895 non-null  int64
#  4   LEGAL NAME                         85895 non-null  object
#  5   DOING BUSINESS AS NAME             85894 non-null  object
#  6   ADDRESS                            85895 non-null  object
#  7   CITY                               85895 non-null  object
#  8   STATE                              85895 non-null  object
#  9   ZIP CODE                           85864 non-null  object
#  10  WARD                               36194 non-null  float64
#  11  PRECINCT                           29194 non-null  float64
#  12  WARD PRECINCT                      36195 non-null  object
#  13  POLICE DISTRICT                    31883 non-null  float64
#  14  LICENSE CODE                       85895 non-null  int64
#  15  LICENSE DESCRIPTION                85895 non-null  object
#  16  LICENSE NUMBER                     85894 non-null  float64
#  17  APPLICATION TYPE                   85895 non-null  object
#  18  APPLICATION CREATED DATE           21235 non-null  object
#  19  APPLICATION REQUIREMENTS COMPLETE  85681 non-null  object
#  20  PAYMENT DATE                       84606 non-null  object
#  21  CONDITIONAL APPROVAL               85895 non-null  object
#  22  LICENSE TERM START DATE            85667 non-null  object
#  23  LICENSE TERM EXPIRATION DATE       85877 non-null  object
#  24  LICENSE APPROVED FOR ISSUANCE      79106 non-null  object
#  25  DATE ISSUED                        85895 non-null  object
#  26  LICENSE STATUS CHANGE DATE         30495 non-null  object
#  27  SSA                                9449 non-null   float64
#  28  LATITUDE                           38649 non-null  float64
#  29  LONGITUDE                          38649 non-null  float64
#  30  LOCATION                           38649 non-null  object
#  31  LICENSE STATUS                     85895 non-null  object
# dtypes: float64(7), int64(4), object(21)
# memory usage: 21.0+ MB

# %%
df.isna().sum()
# Out:
# ID                                       0
# LICENSE ID                               0
# ACCOUNT NUMBER                           0
# SITE NUMBER                              0
# LEGAL NAME                               0
# DOING BUSINESS AS NAME                   1
# ADDRESS                                  0
# CITY                                     0
# STATE                                    0
# ZIP CODE                                31
# WARD                                 49701
# PRECINCT                             56701
# WARD PRECINCT                        49700
# POLICE DISTRICT                      54012
# LICENSE CODE                             0
# LICENSE DESCRIPTION                      0
# LICENSE NUMBER                           1
# APPLICATION TYPE                         0
# APPLICATION CREATED DATE             64660
# APPLICATION REQUIREMENTS COMPLETE      214
# PAYMENT DATE                          1289
# CONDITIONAL APPROVAL                     0
# LICENSE TERM START DATE                228
# LICENSE TERM EXPIRATION DATE            18
# LICENSE APPROVED FOR ISSUANCE         6789
# DATE ISSUED                              0
# LICENSE STATUS CHANGE DATE           55400
# SSA                                  76446
# LATITUDE                             47246
# LONGITUDE                            47246
# LOCATION                             47246
# LICENSE STATUS                           0
# dtype: int64

# %%
df.describe()
# Out:
#          LICENSE ID  ACCOUNT NUMBER   SITE NUMBER          WARD      PRECINCT  \
# count  8.589500e+04    85895.000000  85895.000000  36194.000000  29194.000000
# mean   1.751303e+06   196695.421701      2.556028     28.528927     54.632973
# std    3.358780e+05   126819.343760      8.655706     13.921710    163.174955
# min    3.079300e+04       10.000000      1.000000      1.000000      1.000000
# 25%    1.469024e+06    54615.000000      1.000000     17.000000     12.000000
# 50%    1.778754e+06   248313.000000      1.000000     30.000000     26.000000
# 75%    2.067578e+06   300243.500000      2.000000     42.000000     41.000000
# max    2.456551e+06   397444.000000    417.000000     50.000000    999.000000
#
#        POLICE DISTRICT  LICENSE CODE  LICENSE NUMBER          SSA  \
# count     31883.000000  85895.000000    8.589400e+04  9449.000000
# mean         13.529812   1111.736620    1.228151e+06    29.152080
# std           7.275874    250.020872    7.431487e+05    17.419898
# min           1.000000   1002.000000    1.290000e+02     1.000000
# 25%           8.000000   1010.000000    8.710900e+04    17.000000
# 50%          14.000000   1010.000000    1.442202e+06    28.000000
# 75%          19.000000   1011.000000    1.816581e+06    40.000000
# max         181.000000   8340.000000    2.391410e+06    69.000000
#
#            LATITUDE     LONGITUDE
# count  38649.000000  38649.000000
# mean      41.880952    -87.681165
# std        0.079617      0.056248
# min       41.644694    -87.915285
# 25%       41.834312    -87.719150
# 50%       41.892679    -87.673321
# 75%       41.938624    -87.639509
# max       42.022660    -87.525872

# %%
df.shape
# Out:
# (85895, 32)

# %%
len(df)
# Out:
# 85895

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of                      ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0        35342-20020816     1256593           32811            1
# 1      1358463-20051116     1639294          262311           29
# 2      1980233-20090722     1980233          345008            1
# 3      1476582-20040211     1476582          273121            1
# 4      1141408-20080516     1896750          213785            1
# ...                 ...         ...             ...          ...
# 85890    12652-20120516     2143400            8011            1
# 85891  1821421-20070522     1821421          317725            1
# 85892    74137-20090116     1939358            8458            2
# 85893  2049545-20111016     2110060            2156           43
# 85894  1070196-20040216     1461628          205936            1
#
#                            LEGAL NAME          DOING BUSINESS AS NAME  \
# 0                        CARMEN CAHUE           CLAUDIA'S BRIDAL SHOP
# 1                 ISLA TROPICAL, INC.                   ISLA TROPICAL
# 2                      DJS REMODELING            DJS REMODELING, INC.
# 3            ALL-BRY CONSTRUCTION CO.        ALL-BRY CONSTRUCTION CO.
# 4        MCDONOUGH MECHANICAL SERVICE    MCDONOUGH MECHANICAL SERVICE
# ...                               ...                             ...
# 85890           UNITED PARCEL SERVICE           UNITED PARCEL SERVICE
# 85891  EXPRESS BOARD UP SERVICE, INC.  EXPRESS BOARD UP SERVICE, INC.
# 85892                ARAMARK SMMS LLC       ARAMARK FACILITY SERVICES
# 85893   GENERAL NUTRITION CORPORATION   GENERAL NUTRITION CENTER # 61
# 85894               JUAN CARLOS ERAZO         CASA DE JUAN RESTAURANT
#
#                                     ADDRESS            CITY STATE ZIP CODE  \
# 0                2625 S CENTRAL PARK AVE  1         CHICAGO    IL  60623.0
# 1                       2825 W MONTROSE AVE         CHICAGO    IL    60618
# 2                         1605  CLAVEY RD 1        HIGHLAND    IL    60035
# 3                            8  NORTH TRAIL          LEMONT    IL    60439
# 4                           4081  JOSEPH DR        WAUKEGAN    IL    60087
# ...                                     ...             ...   ...      ...
# 85890                   1400 S JEFFERSON ST         CHICAGO    IL  60607.0
# 85891                     8707  VANGUARD DR  MACHESNEY PARK    IL  61115.0
# 85892              2300  WARRENVILLE RD 1ST   DOWNERS GROVE    IL  60515.0
# 85893  5151 S PULASKI RD SLAB ON GRADE T-21         CHICAGO    IL  60632.0
# 85894                  5814 W FULLERTON AVE         CHICAGO    IL  60639.0
#
#        ...  LICENSE TERM START DATE  LICENSE TERM EXPIRATION DATE  \
# 0      ...      2002-08-16T00:00:00           2003-08-15T00:00:00
# 1      ...      2005-11-16T00:00:00           2006-11-15T00:00:00
# 2      ...      2009-07-22T00:00:00           2011-07-15T00:00:00
# 3      ...      2004-02-11T00:00:00           2005-02-15T00:00:00
# 4      ...      2008-05-16T00:00:00           2010-05-15T00:00:00
# ...    ...                      ...                           ...
# 85890  ...      2012-05-16T00:00:00           2014-05-15T00:00:00
# 85891  ...      2007-05-22T00:00:00           2009-06-15T00:00:00
# 85892  ...      2009-01-16T00:00:00           2011-01-15T00:00:00
# 85893  ...      2011-10-16T00:00:00           2013-10-15T00:00:00
# 85894  ...      2004-02-16T00:00:00           2005-02-15T00:00:00
#
#       LICENSE APPROVED FOR ISSUANCE          DATE ISSUED  \
# 0               2002-08-21T00:00:00  2006-04-11T00:00:00
# 1               2006-04-05T00:00:00  2006-06-12T00:00:00
# 2               2009-07-22T00:00:00  2009-07-22T00:00:00
# 3               2004-02-10T00:00:00  2004-02-11T00:00:00
# 4               2008-06-04T00:00:00  2008-06-05T00:00:00
# ...                             ...                  ...
# 85890           2012-05-07T00:00:00  2012-05-08T00:00:00
# 85891           2007-05-22T00:00:00  2007-05-22T00:00:00
# 85892           2009-01-09T00:00:00  2009-12-08T00:00:00
# 85893           2011-10-03T00:00:00  2011-10-11T00:00:00
# 85894           2003-12-22T00:00:00  2004-02-09T00:00:00
#
#        LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 0                             NaN  25.0  41.843613 -87.714618
# 1             2006-06-15T00:00:00  60.0  41.961132 -87.699626
# 2                             NaN   NaN        NaN        NaN
# 3                             NaN   NaN        NaN        NaN
# 4                             NaN   NaN        NaN        NaN
# ...                           ...   ...        ...        ...
# 85890         2012-12-29T00:00:00   NaN  41.863501 -87.642210
# 85891                         NaN   NaN        NaN        NaN
# 85892                         NaN   NaN        NaN        NaN
# 85893         2012-05-08T00:00:00   NaN  41.799012 -87.723181
# 85894         2005-01-07T00:00:00   NaN  41.924004 -87.771507
#
#                                                 LOCATION LICENSE STATUS
# 0      {'latitude': '41.843612879431845', 'longitude'...            AAI
# 1      {'latitude': '41.96113244107215', 'longitude':...            AAC
# 2                                                    NaN            AAI
# 3                                                    NaN            AAI
# 4                                                    NaN            AAI
# ...                                                  ...            ...
# 85890  {'latitude': '41.86350135244771', 'longitude':...            AAC
# 85891                                                NaN            AAI
# 85892                                                NaN            AAI
# 85893  {'latitude': '41.79901235310339', 'longitude':...            AAC
# 85894  {'latitude': '41.92400390449922', 'longitude':...            AAC
#
# [85895 rows x 32 columns]>

# %%
display(df.head().T)
# Out:
#                                                                                    0  \
# ID                                                                    35342-20020816
# LICENSE ID                                                                   1256593
# ACCOUNT NUMBER                                                                 32811
# SITE NUMBER                                                                        1
# LEGAL NAME                                                              CARMEN CAHUE
# DOING BUSINESS AS NAME                                         CLAUDIA'S BRIDAL SHOP
# ADDRESS                                                   2625 S CENTRAL PARK AVE  1
# CITY                                                                         CHICAGO
# STATE                                                                             IL
# ZIP CODE                                                                     60623.0
# WARD                                                                            22.0
# PRECINCT                                                                        28.0
# WARD PRECINCT                                                                  22-28
# POLICE DISTRICT                                                                 10.0
# LICENSE CODE                                                                    1010
# LICENSE DESCRIPTION                                         Limited Business License
# LICENSE NUMBER                                                               35342.0
# APPLICATION TYPE                                                               RENEW
# APPLICATION CREATED DATE                                                         NaN
# APPLICATION REQUIREMENTS COMPLETE                                2002-06-28T00:00:00
# PAYMENT DATE                                                     2002-08-21T00:00:00
# CONDITIONAL APPROVAL                                                               N
# LICENSE TERM START DATE                                          2002-08-16T00:00:00
# LICENSE TERM EXPIRATION DATE                                     2003-08-15T00:00:00
# LICENSE APPROVED FOR ISSUANCE                                    2002-08-21T00:00:00
# DATE ISSUED                                                      2006-04-11T00:00:00
# LICENSE STATUS CHANGE DATE                                                       NaN
# SSA                                                                             25.0
# LATITUDE                                                                   41.843613
# LONGITUDE                                                                 -87.714618
# LOCATION                           {'latitude': '41.843612879431845', 'longitude'...
# LICENSE STATUS                                                                   AAI
#
#                                                                                    1  \
# ID                                                                  1358463-20051116
# LICENSE ID                                                                   1639294
# ACCOUNT NUMBER                                                                262311
# SITE NUMBER                                                                       29
# LEGAL NAME                                                       ISLA TROPICAL, INC.
# DOING BUSINESS AS NAME                                                 ISLA TROPICAL
# ADDRESS                                                          2825 W MONTROSE AVE
# CITY                                                                         CHICAGO
# STATE                                                                             IL
# ZIP CODE                                                                       60618
# WARD                                                                            33.0
# PRECINCT                                                                        23.0
# WARD PRECINCT                                                                  33-23
# POLICE DISTRICT                                                                 17.0
# LICENSE CODE                                                                    1315
# LICENSE DESCRIPTION                                            Mobile Food Dispenser
# LICENSE NUMBER                                                             1358463.0
# APPLICATION TYPE                                                               RENEW
# APPLICATION CREATED DATE                                                         NaN
# APPLICATION REQUIREMENTS COMPLETE                                2005-09-22T00:00:00
# PAYMENT DATE                                                     2005-11-03T00:00:00
# CONDITIONAL APPROVAL                                                               N
# LICENSE TERM START DATE                                          2005-11-16T00:00:00
# LICENSE TERM EXPIRATION DATE                                     2006-11-15T00:00:00
# LICENSE APPROVED FOR ISSUANCE                                    2006-04-05T00:00:00
# DATE ISSUED                                                      2006-06-12T00:00:00
# LICENSE STATUS CHANGE DATE                                       2006-06-15T00:00:00
# SSA                                                                             60.0
# LATITUDE                                                                   41.961132
# LONGITUDE                                                                 -87.699626
# LOCATION                           {'latitude': '41.96113244107215', 'longitude':...
# LICENSE STATUS                                                                   AAC
#
#                                                       2  \
# ID                                     1980233-20090722
# LICENSE ID                                      1980233
# ACCOUNT NUMBER                                   345008
# SITE NUMBER                                           1
# LEGAL NAME                               DJS REMODELING
# DOING BUSINESS AS NAME             DJS REMODELING, INC.
# ADDRESS                               1605  CLAVEY RD 1
# CITY                                           HIGHLAND
# STATE                                                IL
# ZIP CODE                                          60035
# WARD                                                NaN
# PRECINCT                                            NaN
# WARD PRECINCT                                       NaN
# POLICE DISTRICT                                     NaN
# LICENSE CODE                                       1011
# LICENSE DESCRIPTION                         Home Repair
# LICENSE NUMBER                                1980233.0
# APPLICATION TYPE                                  ISSUE
# APPLICATION CREATED DATE            2009-06-29T00:00:00
# APPLICATION REQUIREMENTS COMPLETE   2009-07-22T00:00:00
# PAYMENT DATE                        2009-07-22T00:00:00
# CONDITIONAL APPROVAL                                  N
# LICENSE TERM START DATE             2009-07-22T00:00:00
# LICENSE TERM EXPIRATION DATE        2011-07-15T00:00:00
# LICENSE APPROVED FOR ISSUANCE       2009-07-22T00:00:00
# DATE ISSUED                         2009-07-22T00:00:00
# LICENSE STATUS CHANGE DATE                          NaN
# SSA                                                 NaN
# LATITUDE                                            NaN
# LONGITUDE                                           NaN
# LOCATION                                            NaN
# LICENSE STATUS                                      AAI
#
#                                                           3  \
# ID                                         1476582-20040211
# LICENSE ID                                          1476582
# ACCOUNT NUMBER                                       273121
# SITE NUMBER                                               1
# LEGAL NAME                         ALL-BRY CONSTRUCTION CO.
# DOING BUSINESS AS NAME             ALL-BRY CONSTRUCTION CO.
# ADDRESS                                      8  NORTH TRAIL
# CITY                                                 LEMONT
# STATE                                                    IL
# ZIP CODE                                              60439
# WARD                                                    NaN
# PRECINCT                                                NaN
# WARD PRECINCT                                           NaN
# POLICE DISTRICT                                         NaN
# LICENSE CODE                                           1010
# LICENSE DESCRIPTION                Limited Business License
# LICENSE NUMBER                                    1476582.0
# APPLICATION TYPE                                      ISSUE
# APPLICATION CREATED DATE                2004-02-10T00:00:00
# APPLICATION REQUIREMENTS COMPLETE       2004-02-10T00:00:00
# PAYMENT DATE                            2004-02-10T00:00:00
# CONDITIONAL APPROVAL                                      N
# LICENSE TERM START DATE                 2004-02-11T00:00:00
# LICENSE TERM EXPIRATION DATE            2005-02-15T00:00:00
# LICENSE APPROVED FOR ISSUANCE           2004-02-10T00:00:00
# DATE ISSUED                             2004-02-11T00:00:00
# LICENSE STATUS CHANGE DATE                              NaN
# SSA                                                     NaN
# LATITUDE                                                NaN
# LONGITUDE                                               NaN
# LOCATION                                                NaN
# LICENSE STATUS                                          AAI
#
#                                                               4
# ID                                             1141408-20080516
# LICENSE ID                                              1896750
# ACCOUNT NUMBER                                           213785
# SITE NUMBER                                                   1
# LEGAL NAME                         MCDONOUGH MECHANICAL SERVICE
# DOING BUSINESS AS NAME             MCDONOUGH MECHANICAL SERVICE
# ADDRESS                                         4081  JOSEPH DR
# CITY                                                   WAUKEGAN
# STATE                                                        IL
# ZIP CODE                                                  60087
# WARD                                                        NaN
# PRECINCT                                                    NaN
# WARD PRECINCT                                               NaN
# POLICE DISTRICT                                             NaN
# LICENSE CODE                                               1010
# LICENSE DESCRIPTION                    Limited Business License
# LICENSE NUMBER                                        1141408.0
# APPLICATION TYPE                                          RENEW
# APPLICATION CREATED DATE                                    NaN
# APPLICATION REQUIREMENTS COMPLETE           2008-03-24T00:00:00
# PAYMENT DATE                                2008-06-04T00:00:00
# CONDITIONAL APPROVAL                                          N
# LICENSE TERM START DATE                     2008-05-16T00:00:00
# LICENSE TERM EXPIRATION DATE                2010-05-15T00:00:00
# LICENSE APPROVED FOR ISSUANCE               2008-06-04T00:00:00
# DATE ISSUED                                 2008-06-05T00:00:00
# LICENSE STATUS CHANGE DATE                                  NaN
# SSA                                                         NaN
# LATITUDE                                                    NaN
# LONGITUDE                                                   NaN
# LOCATION                                                    NaN
# LICENSE STATUS                                              AAI

# %%
# Find the correlation between our independent variables
corr_matrix = df.corr()
corr_matrix
# Out:
# <ipython-input-72-95792adbd8ca>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
#                               site_number      ward  precinct  \
# site_number                      1.000000 -0.015393 -0.030387
# ward                            -0.015393  1.000000  0.053996
# precinct                        -0.030387  0.053996  1.000000
# police_district                  0.011103  0.487728  0.184356
# license_code                     0.109418 -0.040709 -0.026586
# license_number                   0.042001  0.007125 -0.121079
# latitude                        -0.005174  0.667520  0.097531
# longitude                        0.042247 -0.233630 -0.105979
# license_status_change           -0.082947  0.059695  0.372837
# completion_to_start              0.022839 -0.008369 -0.040100
# start_to_expiry                  0.032224 -0.003360 -0.130703
# approval_to_issuance            -0.003519  0.005405  0.024884
# completion_to_payment           -0.004982 -0.015400 -0.008041
# presence_of_enquiry_details      0.007196  0.134229       NaN
# target                          -0.081049  0.033970  0.242497
# license_description_target_1     0.006552  0.033631  0.059296
# state_target_1                  -0.037083  0.009057 -0.003520
# city_target_1                   -0.126579 -0.001859 -0.005919
# license_description_target_2    -0.007294 -0.035371 -0.058228
# state_target_2                   0.037075 -0.009072  0.003520
# city_target_2                    0.126589  0.001857  0.005919
# license_description_target_3     0.006496  0.007117 -0.028390
# state_target_3                   0.037377 -0.007710  0.003463
# city_target_3                    0.125400  0.001788  0.005934
# license_description_target_4    -0.002642 -0.004523  0.041680
# state_target_4                   0.037377 -0.007710  0.003463
# city_target_4                    0.125726  0.001790  0.005935
# license_description_target_5    -0.070473  0.025148  0.036645
# state_target_5                   0.037377 -0.007710  0.003463
# city_target_5                   -0.011887  0.001270 -0.001503
#
#                               police_district  license_code  license_number  \
# site_number                          0.011103      0.109418        0.042001
# ward                                 0.487728     -0.040709        0.007125
# precinct                             0.184356     -0.026586       -0.121079
# police_district                      1.000000      0.048442       -0.042338
# license_code                         0.048442      1.000000        0.069720
# license_number                      -0.042338      0.069720        1.000000
# latitude                             0.619882     -0.009484       -0.010265
# longitude                           -0.455247     -0.001010        0.029111
# license_status_change                0.027580     -0.136106       -0.067119
# completion_to_start                 -0.009530     -0.013991       -0.048358
# start_to_expiry                     -0.018686      0.004363        0.252221
# approval_to_issuance                 0.020588     -0.005608       -0.052315
# completion_to_payment               -0.011385     -0.038443       -0.105381
# presence_of_enquiry_details               NaN     -0.074096        0.255090
# target                               0.013175     -0.109690       -0.063456
# license_description_target_1        -0.027039     -0.272821       -0.012707
# state_target_1                      -0.014502      0.010959       -0.011793
# city_target_1                       -0.000440     -0.055656       -0.046331
# license_description_target_2         0.026057      0.273220        0.018617
# state_target_2                       0.014497     -0.010890        0.011831
# city_target_2                        0.000438      0.055727        0.046380
# license_description_target_3         0.016829      0.080684       -0.062125
# state_target_3                       0.014762     -0.016031        0.008899
# city_target_3                        0.000173      0.050772        0.042545
# license_description_target_4         0.018141      0.060786       -0.032467
# state_target_4                       0.014762     -0.016031        0.008899
# city_target_4                        0.000182      0.050245        0.042198
# license_description_target_5         0.000158     -0.332524        0.058156
# state_target_5                       0.014762     -0.016031        0.008899
# city_target_5                        0.004023     -0.015196       -0.006044
#
#                               latitude  longitude  license_status_change  \
# site_number                  -0.005174   0.042247              -0.082947
# ward                          0.667520  -0.233630               0.059695
# precinct                      0.097531  -0.105979               0.372837
# police_district               0.619882  -0.455247               0.027580
# license_code                 -0.009484  -0.001010              -0.136106
# license_number               -0.010265   0.029111              -0.067119
# latitude                      1.000000  -0.404510               0.010159
# longitude                    -0.404510   1.000000              -0.009596
# license_status_change         0.010159  -0.009596               1.000000
# completion_to_start          -0.003205  -0.006220              -0.052214
# start_to_expiry              -0.022032  -0.013572              -0.219192
# approval_to_issuance          0.005643   0.003440               0.054046
# completion_to_payment        -0.009425   0.005460               0.034511
# presence_of_enquiry_details   0.034470   0.010487               0.062079
# target                       -0.004404  -0.002988               0.892784
# license_description_target_1 -0.003567  -0.000476               0.480762
# state_target_1               -0.017902   0.040886               0.138149
# city_target_1                 0.020550  -0.029340               0.635319
# license_description_target_2  0.000894  -0.001167              -0.479066
# state_target_2                0.017891  -0.040885              -0.138149
# city_target_2                -0.020554   0.029310              -0.635317
# license_description_target_3  0.027095   0.016730              -0.170008
# state_target_3                0.018656  -0.040718              -0.137128
# city_target_3                -0.020648   0.031503              -0.632809
# license_description_target_4  0.022353  -0.007489              -0.060224
# state_target_4                0.018656  -0.040718              -0.137128
# city_target_4                -0.020648   0.031495              -0.633745
# license_description_target_5  0.009657  -0.073631               0.196479
# state_target_5                0.018656  -0.040718              -0.137128
# city_target_5                 0.011142  -0.001065               0.046937
#
#                               completion_to_start  ...  city_target_2  \
# site_number                              0.022839  ...       0.126589
# ward                                    -0.008369  ...       0.001857
# precinct                                -0.040100  ...       0.005919
# police_district                         -0.009530  ...       0.000438
# license_code                            -0.013991  ...       0.055727
# license_number                          -0.048358  ...       0.046380
# latitude                                -0.003205  ...      -0.020554
# longitude                               -0.006220  ...       0.029310
# license_status_change                   -0.052214  ...      -0.635317
# completion_to_start                      1.000000  ...       0.036023
# start_to_expiry                         -0.067815  ...       0.177984
# approval_to_issuance                     0.198971  ...      -0.040946
# completion_to_payment                    0.105508  ...      -0.032100
# presence_of_enquiry_details             -0.030247  ...       0.262569
# target                                  -0.042263  ...      -0.560211
# license_description_target_1            -0.036810  ...      -0.425933
# state_target_1                          -0.017729  ...      -0.117085
# city_target_1                           -0.036028  ...      -0.999999
# license_description_target_2             0.035441  ...       0.424471
# state_target_2                           0.017733  ...       0.117125
# city_target_2                            0.036023  ...       1.000000
# license_description_target_3             0.026851  ...       0.149715
# state_target_3                           0.017297  ...       0.113228
# city_target_3                            0.036003  ...       0.995764
# license_description_target_4             0.012895  ...       0.076954
# state_target_4                           0.017297  ...       0.113228
# city_target_4                            0.036322  ...       0.997286
# license_description_target_5            -0.048606  ...      -0.288912
# state_target_5                           0.017297  ...       0.113228
# city_target_5                            0.000946  ...      -0.075073
#
#                               license_description_target_3  state_target_3  \
# site_number                                       0.006496        0.037377
# ward                                              0.007117       -0.007710
# precinct                                         -0.028390        0.003463
# police_district                                   0.016829        0.014762
# license_code                                      0.080684       -0.016031
# license_number                                   -0.062125        0.008899
# latitude                                          0.027095        0.018656
# longitude                                         0.016730       -0.040718
# license_status_change                            -0.170008       -0.137128
# completion_to_start                               0.026851        0.017297
# start_to_expiry                                   0.003812        0.030153
# approval_to_issuance                             -0.011273       -0.015250
# completion_to_payment                            -0.003860       -0.009496
# presence_of_enquiry_details                      -0.023427        0.057182
# target                                           -0.002772       -0.120609
# license_description_target_1                     -0.353619       -0.088180
# state_target_1                                   -0.031584       -0.992595
# city_target_1                                    -0.149727       -0.113256
# license_description_target_2                      0.273904        0.087783
# state_target_2                                    0.031576        0.992397
# city_target_2                                     0.149715        0.113228
# license_description_target_3                      1.000000        0.031899
# state_target_3                                    0.031899        1.000000
# city_target_3                                     0.150077        0.113559
# license_description_target_4                      0.559446        0.017180
# state_target_4                                    0.031899        1.000000
# city_target_4                                     0.150327        0.113020
# license_description_target_5                     -0.116434        0.030402
# state_target_5                                    0.031899        1.000000
# city_target_5                                    -0.011366        0.010522
#
#                               city_target_3  license_description_target_4  \
# site_number                        0.125400                     -0.002642
# ward                               0.001788                     -0.004523
# precinct                           0.005934                      0.041680
# police_district                    0.000173                      0.018141
# license_code                       0.050772                      0.060786
# license_number                     0.042545                     -0.032467
# latitude                          -0.020648                      0.022353
# longitude                          0.031503                     -0.007489
# license_status_change             -0.632809                     -0.060224
# completion_to_start                0.036003                      0.012895
# start_to_expiry                    0.177567                      0.003772
# approval_to_issuance              -0.040881                     -0.003928
# completion_to_payment             -0.030830                     -0.003982
# presence_of_enquiry_details        0.262924                      0.000389
# target                            -0.557752                      0.032896
# license_description_target_1      -0.424988                     -0.125272
# state_target_1                    -0.116674                     -0.017051
# city_target_1                     -0.995868                     -0.076959
# license_description_target_2       0.423467                      0.077070
# state_target_2                     0.116704                      0.017047
# city_target_2                      0.995764                      0.076954
# license_description_target_3       0.150077                      0.559446
# state_target_3                     0.113559                      0.017180
# city_target_3                      1.000000                      0.077054
# license_description_target_4       0.077054                      1.000000
# state_target_4                     0.113559                      0.017180
# city_target_4                      0.998441                      0.077173
# license_description_target_5      -0.288842                     -0.056688
# state_target_5                     0.113559                      0.017180
# city_target_5                     -0.076044                     -0.005713
#
#                               state_target_4  city_target_4  \
# site_number                         0.037377       0.125726
# ward                               -0.007710       0.001790
# precinct                            0.003463       0.005935
# police_district                     0.014762       0.000182
# license_code                       -0.016031       0.050245
# license_number                      0.008899       0.042198
# latitude                            0.018656      -0.020648
# longitude                          -0.040718       0.031495
# license_status_change              -0.137128      -0.633745
# completion_to_start                 0.017297       0.036322
# start_to_expiry                     0.030153       0.177991
# approval_to_issuance               -0.015250      -0.041069
# completion_to_payment              -0.009496      -0.031284
# presence_of_enquiry_details         0.057182       0.263331
# target                             -0.120609      -0.558667
# license_description_target_1       -0.088180      -0.425531
# state_target_1                     -0.992595      -0.116120
# city_target_1                      -0.113256      -0.997353
# license_description_target_2        0.087783       0.424003
# state_target_2                      0.992397       0.116150
# city_target_2                       0.113228       0.997286
# license_description_target_3        0.031899       0.150327
# state_target_3                      1.000000       0.113020
# city_target_3                       0.113559       0.998441
# license_description_target_4        0.017180       0.077173
# state_target_4                      1.000000       0.113020
# city_target_4                       0.113020       1.000000
# license_description_target_5        0.030402      -0.289625
# state_target_5                      1.000000       0.113020
# city_target_5                       0.010522      -0.075685
#
#                               license_description_target_5  state_target_5  \
# site_number                                      -0.070473        0.037377
# ward                                              0.025148       -0.007710
# precinct                                          0.036645        0.003463
# police_district                                   0.000158        0.014762
# license_code                                     -0.332524       -0.016031
# license_number                                    0.058156        0.008899
# latitude                                          0.009657        0.018656
# longitude                                        -0.073631       -0.040718
# license_status_change                             0.196479       -0.137128
# completion_to_start                              -0.048606        0.017297
# start_to_expiry                                  -0.053885        0.030153
# approval_to_issuance                              0.013206       -0.015250
# completion_to_payment                             0.014985       -0.009496
# presence_of_enquiry_details                      -0.042744        0.057182
# target                                            0.164505       -0.120609
# license_description_target_1                      0.408682       -0.088180
# state_target_1                                   -0.027337       -0.992595
# city_target_1                                     0.288907       -0.113256
# license_description_target_2                     -0.409813        0.087783
# state_target_2                                    0.027294        0.992397
# city_target_2                                    -0.288912        0.113228
# license_description_target_3                     -0.116434        0.031899
# state_target_3                                    0.030402        1.000000
# city_target_3                                    -0.288842        0.113559
# license_description_target_4                     -0.056688        0.017180
# state_target_4                                    0.030402        1.000000
# city_target_4                                    -0.289625        0.113020
# license_description_target_5                      1.000000        0.030402
# state_target_5                                    0.030402        1.000000
# city_target_5                                     0.042548        0.010522
#
#                               city_target_5
# site_number                       -0.011887
# ward                               0.001270
# precinct                          -0.001503
# police_district                    0.004023
# license_code                      -0.015196
# license_number                    -0.006044
# latitude                           0.011142
# longitude                         -0.001065
# license_status_change              0.046937
# completion_to_start                0.000946
# start_to_expiry                   -0.015713
# approval_to_issuance               0.000489
# completion_to_payment              0.005586
# presence_of_enquiry_details       -0.019846
# target                             0.042426
# license_description_target_1       0.032611
# state_target_1                    -0.010823
# city_target_1                      0.074153
# license_description_target_2      -0.032511
# state_target_2                     0.010826
# city_target_2                     -0.075073
# license_description_target_3      -0.011366
# state_target_3                     0.010522
# city_target_3                     -0.076044
# license_description_target_4      -0.005713
# state_target_4                     0.010522
# city_target_4                     -0.075685
# license_description_target_5       0.042548
# state_target_5                     0.010522
# city_target_5                      1.000000
#
# [30 rows x 30 columns]

# %%
corr_matrix = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix,
            annot=True,
            linewidths=0.5,
            fmt= ".2f",
            cmap="YlGnBu");
# Out:
# <ipython-input-73-ce1eccacef98>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %% [markdown]
# # Data processing

# %%
# change the columns name
new_col_name = [col.replace(" ","_").lower() for col in df.columns]
df.columns = new_col_name

# %%
# dropping unncessary columns
df = df.drop(["id", "license_id", "ssa", "location", "application_created_date", "account_number", "address"], axis=1)

# %%
df.head()
# Out:
#    site_number                    legal_name        doing_business_as_name  \
# 0            1                  CARMEN CAHUE         CLAUDIA'S BRIDAL SHOP
# 1           29           ISLA TROPICAL, INC.                 ISLA TROPICAL
# 2            1                DJS REMODELING          DJS REMODELING, INC.
# 3            1      ALL-BRY CONSTRUCTION CO.      ALL-BRY CONSTRUCTION CO.
# 4            1  MCDONOUGH MECHANICAL SERVICE  MCDONOUGH MECHANICAL SERVICE
#
#        city state zip_code  ward  precinct ward_precinct  police_district  \
# 0   CHICAGO    IL  60623.0  22.0      28.0         22-28             10.0
# 1   CHICAGO    IL    60618  33.0      23.0         33-23             17.0
# 2  HIGHLAND    IL    60035   NaN       NaN           NaN              NaN
# 3    LEMONT    IL    60439   NaN       NaN           NaN              NaN
# 4  WAUKEGAN    IL    60087   NaN       NaN           NaN              NaN
#
#    ...         payment_date conditional_approval  license_term_start_date  \
# 0  ...  2002-08-21T00:00:00                    N      2002-08-16T00:00:00
# 1  ...  2005-11-03T00:00:00                    N      2005-11-16T00:00:00
# 2  ...  2009-07-22T00:00:00                    N      2009-07-22T00:00:00
# 3  ...  2004-02-10T00:00:00                    N      2004-02-11T00:00:00
# 4  ...  2008-06-04T00:00:00                    N      2008-05-16T00:00:00
#
#   license_term_expiration_date license_approved_for_issuance  \
# 0          2003-08-15T00:00:00           2002-08-21T00:00:00
# 1          2006-11-15T00:00:00           2006-04-05T00:00:00
# 2          2011-07-15T00:00:00           2009-07-22T00:00:00
# 3          2005-02-15T00:00:00           2004-02-10T00:00:00
# 4          2010-05-15T00:00:00           2008-06-04T00:00:00
#
#            date_issued license_status_change_date   latitude  longitude  \
# 0  2006-04-11T00:00:00                        NaN  41.843613 -87.714618
# 1  2006-06-12T00:00:00        2006-06-15T00:00:00  41.961132 -87.699626
# 2  2009-07-22T00:00:00                        NaN        NaN        NaN
# 3  2004-02-11T00:00:00                        NaN        NaN        NaN
# 4  2008-06-05T00:00:00                        NaN        NaN        NaN
#
#   license_status
# 0            AAI
# 1            AAC
# 2            AAI
# 3            AAI
# 4            AAI
#
# [5 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# site_number                              0
# legal_name                               0
# doing_business_as_name                   1
# city                                     0
# state                                    0
# zip_code                                31
# ward                                 49701
# precinct                             56701
# ward_precinct                        49700
# police_district                      54012
# license_code                             0
# license_description                      0
# license_number                           1
# application_type                         0
# application_requirements_complete      214
# payment_date                          1289
# conditional_approval                     0
# license_term_start_date                228
# license_term_expiration_date            18
# license_approved_for_issuance         6789
# date_issued                              0
# license_status_change_date           55400
# latitude                             47246
# longitude                            47246
# license_status                           0
# dtype: int64

# %%
df["license_status_change"] = np.where(df.license_status_change_date.isnull(),1,0)

# %%
pd.crosstab(df.license_status_change,df.license_status)
# Out:
# license_status           AAC    AAI  INQ  REA  REV
# license_status_change
# 0                      30200      0    2    3  290
# 1                          0  55400    0    0    0

# %%
df.head()
# Out:
#    site_number                    legal_name        doing_business_as_name  \
# 0            1                  CARMEN CAHUE         CLAUDIA'S BRIDAL SHOP
# 1           29           ISLA TROPICAL, INC.                 ISLA TROPICAL
# 2            1                DJS REMODELING          DJS REMODELING, INC.
# 3            1      ALL-BRY CONSTRUCTION CO.      ALL-BRY CONSTRUCTION CO.
# 4            1  MCDONOUGH MECHANICAL SERVICE  MCDONOUGH MECHANICAL SERVICE
#
#        city state zip_code  ward  precinct ward_precinct  police_district  \
# 0   CHICAGO    IL  60623.0  22.0      28.0         22-28             10.0
# 1   CHICAGO    IL    60618  33.0      23.0         33-23             17.0
# 2  HIGHLAND    IL    60035   NaN       NaN           NaN              NaN
# 3    LEMONT    IL    60439   NaN       NaN           NaN              NaN
# 4  WAUKEGAN    IL    60087   NaN       NaN           NaN              NaN
#
#    ...  conditional_approval license_term_start_date  \
# 0  ...                     N     2002-08-16T00:00:00
# 1  ...                     N     2005-11-16T00:00:00
# 2  ...                     N     2009-07-22T00:00:00
# 3  ...                     N     2004-02-11T00:00:00
# 4  ...                     N     2008-05-16T00:00:00
#
#    license_term_expiration_date license_approved_for_issuance  \
# 0           2003-08-15T00:00:00           2002-08-21T00:00:00
# 1           2006-11-15T00:00:00           2006-04-05T00:00:00
# 2           2011-07-15T00:00:00           2009-07-22T00:00:00
# 3           2005-02-15T00:00:00           2004-02-10T00:00:00
# 4           2010-05-15T00:00:00           2008-06-04T00:00:00
#
#            date_issued license_status_change_date   latitude  longitude  \
# 0  2006-04-11T00:00:00                        NaN  41.843613 -87.714618
# 1  2006-06-12T00:00:00        2006-06-15T00:00:00  41.961132 -87.699626
# 2  2009-07-22T00:00:00                        NaN        NaN        NaN
# 3  2004-02-11T00:00:00                        NaN        NaN        NaN
# 4  2008-06-05T00:00:00                        NaN        NaN        NaN
#
#   license_status license_status_change
# 0            AAI                     1
# 1            AAC                     0
# 2            AAI                     1
# 3            AAI                     1
# 4            AAI                     1
#
# [5 rows x 26 columns]

# %%
df.head().T
# Out:
#                                                           0  \
# site_number                                               1
# legal_name                                     CARMEN CAHUE
# doing_business_as_name                CLAUDIA'S BRIDAL SHOP
# city                                                CHICAGO
# state                                                    IL
# zip_code                                            60623.0
# ward                                                   22.0
# precinct                                               28.0
# ward_precinct                                         22-28
# police_district                                        10.0
# license_code                                           1010
# license_description                Limited Business License
# license_number                                      35342.0
# application_type                                      RENEW
# application_requirements_complete       2002-06-28 00:00:00
# payment_date                            2002-08-21 00:00:00
# conditional_approval                                      N
# license_term_start_date                 2002-08-16 00:00:00
# license_term_expiration_date            2003-08-15 00:00:00
# license_approved_for_issuance           2002-08-21 00:00:00
# date_issued                             2006-04-11 00:00:00
# license_status_change_date                              NaN
# latitude                                          41.843613
# longitude                                        -87.714618
# license_status                                          AAI
# license_status_change                                     1
#
#                                                        1  \
# site_number                                           29
# legal_name                           ISLA TROPICAL, INC.
# doing_business_as_name                     ISLA TROPICAL
# city                                             CHICAGO
# state                                                 IL
# zip_code                                           60618
# ward                                                33.0
# precinct                                            23.0
# ward_precinct                                      33-23
# police_district                                     17.0
# license_code                                        1315
# license_description                Mobile Food Dispenser
# license_number                                 1358463.0
# application_type                                   RENEW
# application_requirements_complete    2005-09-22 00:00:00
# payment_date                         2005-11-03 00:00:00
# conditional_approval                                   N
# license_term_start_date              2005-11-16 00:00:00
# license_term_expiration_date         2006-11-15 00:00:00
# license_approved_for_issuance        2006-04-05 00:00:00
# date_issued                          2006-06-12 00:00:00
# license_status_change_date           2006-06-15T00:00:00
# latitude                                       41.961132
# longitude                                     -87.699626
# license_status                                       AAC
# license_status_change                                  0
#
#                                                       2  \
# site_number                                           1
# legal_name                               DJS REMODELING
# doing_business_as_name             DJS REMODELING, INC.
# city                                           HIGHLAND
# state                                                IL
# zip_code                                          60035
# ward                                                NaN
# precinct                                            NaN
# ward_precinct                                       NaN
# police_district                                     NaN
# license_code                                       1011
# license_description                         Home Repair
# license_number                                1980233.0
# application_type                                  ISSUE
# application_requirements_complete   2009-07-22 00:00:00
# payment_date                        2009-07-22 00:00:00
# conditional_approval                                  N
# license_term_start_date             2009-07-22 00:00:00
# license_term_expiration_date        2011-07-15 00:00:00
# license_approved_for_issuance       2009-07-22 00:00:00
# date_issued                         2009-07-22 00:00:00
# license_status_change_date                          NaN
# latitude                                            NaN
# longitude                                           NaN
# license_status                                      AAI
# license_status_change                                 1
#
#                                                           3  \
# site_number                                               1
# legal_name                         ALL-BRY CONSTRUCTION CO.
# doing_business_as_name             ALL-BRY CONSTRUCTION CO.
# city                                                 LEMONT
# state                                                    IL
# zip_code                                              60439
# ward                                                    NaN
# precinct                                                NaN
# ward_precinct                                           NaN
# police_district                                         NaN
# license_code                                           1010
# license_description                Limited Business License
# license_number                                    1476582.0
# application_type                                      ISSUE
# application_requirements_complete       2004-02-10 00:00:00
# payment_date                            2004-02-10 00:00:00
# conditional_approval                                      N
# license_term_start_date                 2004-02-11 00:00:00
# license_term_expiration_date            2005-02-15 00:00:00
# license_approved_for_issuance           2004-02-10 00:00:00
# date_issued                             2004-02-11 00:00:00
# license_status_change_date                              NaN
# latitude                                                NaN
# longitude                                               NaN
# license_status                                          AAI
# license_status_change                                     1
#
#                                                               4
# site_number                                                   1
# legal_name                         MCDONOUGH MECHANICAL SERVICE
# doing_business_as_name             MCDONOUGH MECHANICAL SERVICE
# city                                                   WAUKEGAN
# state                                                        IL
# zip_code                                                  60087
# ward                                                        NaN
# precinct                                                    NaN
# ward_precinct                                               NaN
# police_district                                             NaN
# license_code                                               1010
# license_description                    Limited Business License
# license_number                                        1141408.0
# application_type                                          RENEW
# application_requirements_complete           2008-03-24 00:00:00
# payment_date                                2008-06-04 00:00:00
# conditional_approval                                          N
# license_term_start_date                     2008-05-16 00:00:00
# license_term_expiration_date                2010-05-15 00:00:00
# license_approved_for_issuance               2008-06-04 00:00:00
# date_issued                                 2008-06-05 00:00:00
# license_status_change_date                                  NaN
# latitude                                                    NaN
# longitude                                                   NaN
# license_status                                              AAI
# license_status_change                                         1

# %%
# convert string object into date
df.application_requirements_complete = pd.DatetimeIndex(df.application_requirements_complete)
df.payment_date = pd.DatetimeIndex(df.payment_date)
df.license_term_start_date = pd.DatetimeIndex(df.license_term_start_date)
df.license_term_expiration_date = pd.DatetimeIndex(df.license_term_expiration_date)
df.license_approved_for_issuance = pd.DatetimeIndex(df.license_approved_for_issuance)
df.date_issued = pd.DatetimeIndex(df.date_issued)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b4fac22e737> in <cell line: 2>()
#       1 # convert string object into date
# ----> 2 df.application_requirements_complete = pd.DatetimeIndex(df.application_requirements_complete)
#       3 df.payment_date = pd.DatetimeIndex(df.payment_date)
#       4 df.license_term_start_date = pd.DatetimeIndex(df.license_term_start_date)
#       5 df.license_term_expiration_date = pd.DatetimeIndex(df.license_term_expiration_date)
#
# NameError: name 'pd' is not defined

# %%
# Find no.of days btw different application status date
df["completion_to_start"] = (df.license_term_start_date - df.application_requirements_complete).dt.days
df["start_to_expiry"] =  (df.license_term_expiration_date - df.license_term_start_date).dt.days
df["approval_to_issuance"] = (df.date_issued - df.license_approved_for_issuance).dt.days
df["completion_to_payment"] = (df.payment_date - df.application_requirements_complete).dt.days

df["presence_of_enquiry_details"] = np.where(df.ward.isnull() | df.ward_precinct.isnull() | df.police_district | df.precinct , 0 ,1 )

df["target"] = df[['license_status']].apply(lambda col:pd.Categorical(col).codes)

# %%
df.city.unique()
# Out:
# array(['CHICAGO', 'HIGHLAND', 'LEMONT', ..., 'ABERDEEN', 'PENSACOLA',
#        'MACHESNEY PARK'], dtype=object)

# %%
df.dtypes()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85895 entries, 0 to 85894
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   site_number                        85895 non-null  int64
#  1   legal_name                         85895 non-null  object
#  2   doing_business_as_name             85894 non-null  object
#  3   city                               85895 non-null  object
#  4   state                              85895 non-null  object
#  5   zip_code                           85864 non-null  object
#  6   ward                               36194 non-null  float64
#  7   precinct                           29194 non-null  float64
#  8   ward_precinct                      36195 non-null  object
#  9   police_district                    31883 non-null  float64
#  10  license_code                       85895 non-null  int64
#  11  license_description                85895 non-null  object
#  12  license_number                     85894 non-null  float64
#  13  application_type                   85895 non-null  object
#  14  application_requirements_complete  85681 non-null  datetime64[ns]
#  15  payment_date                       84606 non-null  datetime64[ns]
#  16  conditional_approval               85895 non-null  object
#  17  license_term_start_date            85667 non-null  datetime64[ns]
#  18  license_term_expiration_date       85877 non-null  datetime64[ns]
#  19  license_approved_for_issuance      79106 non-null  datetime64[ns]
#  20  date_issued                        85895 non-null  datetime64[ns]
#  21  license_status_change_date         30495 non-null  object
#  22  latitude                           38649 non-null  float64
#  23  longitude                          38649 non-null  float64
#  24  license_status                     85895 non-null  object
#  25  license_status_change              85895 non-null  int64
#  26  completion_to_start                85500 non-null  float64
#  27  start_to_expiry                    85667 non-null  float64
#  28  approval_to_issuance               79106 non-null  float64
#  29  completion_to_payment              84495 non-null  float64
#  30  presence_of_enquiry_details        85895 non-null  int64
#  31  target                             85895 non-null  int8
# dtypes: datetime64[ns](6), float64(10), int64(4), int8(1), object(11)
# memory usage: 20.4+ MB

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
import category_encoders as ce

# %%
enc=ce.OneHotEncoder().fit(df.target.astype(str))
y_onehot=enc.transform(df.target.astype(str))
print(y_onehot.columns)
# Out:
# Index(['target_1', 'target_2', 'target_3', 'target_4', 'target_5'], dtype='object')

# %% [markdown]
# # Target encoding

# %%
# astype(str) in case of numeric labels
enc = ce.OneHotEncoder().fit(df.target.astype(str))

# Transform target into onehot encoded form
y_onehot = enc.transform(df.target.astype(str))

class_names = y_onehot.columns

# For each class in target variable
for class_ in class_names:

  # Initialize a Target Encoder
  enc = ce.TargetEncoder(smoothing=0)

  # Fit & Transform features with respect to each class in target
  temp = enc.fit_transform(df[["license_description", "state", "city"]], y_onehot[class_])

  # Rename columns to show which class was used as the target
  temp.columns = [str(x) + '_' + str(class_) for x in temp.columns]

  # Concatenate the original DataFrame and the newly encoded features
  df = pd.concat([df, temp], axis=1)

# %%
df.dtypes
# Out:
# site_number                                   int64
# legal_name                                   object
# doing_business_as_name                       object
# city                                         object
# state                                        object
# zip_code                                     object
# ward                                        float64
# precinct                                    float64
# ward_precinct                                object
# police_district                             float64
# license_code                                  int64
# license_description                          object
# license_number                              float64
# application_type                             object
# application_requirements_complete    datetime64[ns]
# payment_date                         datetime64[ns]
# conditional_approval                         object
# license_term_start_date              datetime64[ns]
# license_term_expiration_date         datetime64[ns]
# license_approved_for_issuance        datetime64[ns]
# date_issued                          datetime64[ns]
# license_status_change_date                   object
# latitude                                    float64
# longitude                                   float64
# license_status                               object
# license_status_change                         int64
# completion_to_start                         float64
# start_to_expiry                             float64
# approval_to_issuance                        float64
# completion_to_payment                       float64
# presence_of_enquiry_details                   int64
# target                                         int8
# license_description_target_1                float64
# state_target_1                              float64
# city_target_1                               float64
# license_description_target_2                float64
# state_target_2                              float64
# city_target_2                               float64
# license_description_target_3                float64
# state_target_3                              float64
# city_target_3                               float64
# license_description_target_4                float64
# state_target_4                              float64
# city_target_4                               float64
# license_description_target_5                float64
# state_target_5                              float64
# city_target_5                               float64
# dtype: object

# %%
df.license_status.value_counts()
# Out:
# AAI    55400
# AAC    30200
# REV      290
# REA        3
# INQ        2
# Name: license_status, dtype: int64

# %%
df.license_status.value_counts(normalize=True).mul(100).round(3).astype(str) + '%'
# Out:
# AAI    64.497%
# AAC    35.159%
# REV     0.338%
# REA     0.003%
# INQ     0.002%
# Name: license_status, dtype: object

# %%
np.sort(df.target.unique()).tolist()
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# # working on undersampling and oversampling

# %%
# Undersampling
df_0 = df[df.target==0].sample(frac=0.3,replace=False)
df_1 = df[df.target==1].sample(frac=0.3,replace=False)
# oversamplig
df_2 = df[df.target==2].sample(frac=200,replace=True)
df_3 = df[df.target==3].sample(frac=100,replace=True)
df_4 = df[df.target==4].sample(frac=2,replace=True)

sampled_df = pd.concat([df_0,df_1,df_2,df_3,df_4])

sampled_df.target.value_counts()
# Out:
# 1    16620
# 0     9060
# 4      580
# 2      400
# 3      300
# Name: target, dtype: int64

# %% [markdown]
# # mean imputation

# %%
X = sampled_df[['latitude', 'longitude',
       'completion_to_start',
       'start_to_expiry', 'approval_to_issuance', 'completion_to_payment',
       'presence_of_enquiry_details',  'license_description_target_1',
       'state_target_1', 'city_target_1', 'license_description_target_2',
       'state_target_2', 'city_target_2', 'license_description_target_3',
       'state_target_3', 'city_target_3', 'license_description_target_4',
       'state_target_4', 'city_target_4', 'license_description_target_5',
       'state_target_5', 'city_target_5']]

y = sampled_df['target']

# %%
X = X.fillna(X.mean())

# %%
from xgboost import XGBRegressor

# %%
# Train/test preparation
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
# Put models in a dictionary
models = {"KNN": KNeighborsClassifier(),
          "Logistic Regression": LogisticRegression(),
          "Random Forest": RandomForestClassifier(),
          "XGB Regressor": XGBRegressor()}

# Create function to fit and score models
def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    Fits and evaluates given machine learning models.
    models : a dict of different Scikit-Learn machine learning models
    X_train : training data
    X_test : testing data
    y_train : labels assosciated with training data
    y_test : labels assosciated with test data
    """
    # Random seed for reproducible results
    np.random.seed(42)
    # Make a list to keep model scores
    model_scores = {}
    # Loop through models
    for name, model in models.items():
        # Fit the model to the data
        model.fit(X_train, y_train)
        # Evaluate the model and append its score to model_scores
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test=X_test,
                             y_train=y_train,
                             y_test=y_test)
model_scores
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'KNN': 0.7768916913946587,
#  'Logistic Regression': 0.6572700296735905,
#  'Random Forest': 0.8961424332344213,
#  'XGB Regressor': 0.695537421299818}

# %% [markdown]
# # MODEL COMPARISON

# %%
model_compare = pd.DataFrame(model_scores, index=['accuracy'])
model_compare.T.plot.bar();

# %% [markdown]
# # Hyperparameter tuning and cross validation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Defining the classifier
knn = KNeighborsClassifier()

# Define parameter grid (here we search from 1 to 10 neighbors)
params = {'n_neighbors': list(range(1, 11)),
          'weights': ['uniform', 'distance']}

# Instantiate GridSearchCV
grid_search = GridSearchCV(knn, params, cv=5)  # 5-fold cross-validation

# Fit the model to the data
grid_search.fit(X_train, y_train)

# Getting the best parameters
print('Best Parameters:', grid_search.best_params_)

# You can now create a new KNN classifier with the "best" parameters
best_knn = KNeighborsClassifier(n_neighbors=grid_search.best_params_['n_neighbors'],
                                weights=grid_search.best_params_['weights'])
best_knn.fit(X_train, y_train)
# Out:
# Best Parameters: {'n_neighbors': 10, 'weights': 'distance'}
# KNeighborsClassifier(n_neighbors=10, weights='distance')

# %%
# Evaluate the model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Predict the responses for test dataset
y_pred = best_knn.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",accuracy_score(y_test, y_pred))

# Confusion Matrix
print("\nConfusion Matrix:\n",confusion_matrix(y_test, y_pred))

# Classification Report
print("\nClassification Report:\n",classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8037833827893175
#
# Confusion Matrix:
#  [[1202  632    0    2   11]
#  [ 384 2885    0    0    5]
#  [   0    0   76    0    0]
#  [   0    0    0   68    0]
#  [  21    3    0    0  103]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.65      0.70      1847
#            1       0.82      0.88      0.85      3274
#            2       1.00      1.00      1.00        76
#            3       0.97      1.00      0.99        68
#            4       0.87      0.81      0.84       127
#
#     accuracy                           0.80      5392
#    macro avg       0.88      0.87      0.87      5392
# weighted avg       0.80      0.80      0.80      5392

# %% [markdown]
# # lets tune our Random forest classifier

# %%
# Different RandomForestClassifier hyperparameters
rf_grid = {"n_estimators": np.arange(10, 1000, 50),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2)}

# %%
# Setup random seed
np.random.seed(42)

# Setup random hyperparameter search for RandomForestClassifier
rs_rf = RandomizedSearchCV(RandomForestClassifier(),
                           param_distributions=rf_grid,
                           cv=5,
                           n_iter=20,
                           verbose=True)

# Fit random hyperparameter search model
rs_rf.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits

# %%
# Find the best parameters
rs_rf.best_params_
# Out:
# {'n_estimators': 510,
#  'min_samples_split': 14,
#  'min_samples_leaf': 1,
#  'max_depth': None}

# %%
# Evaluate the randomized search random forest model
rs_rf.score(X_test, y_test)
# Out:
# 0.8929896142433235

# %%
param_test1 = {
 'max_depth':range(3,10,2),
 'min_child_weight':range(1,6,2)
}
gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=140, max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27),
 param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch1.fit(train[predictors],train[target])
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-d56ee773cf05> in <cell line: 5>()
#       3  'min_child_weight':range(1,6,2)
#       4 }
# ----> 5 gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=140, max_depth=5,
#       6  min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
#       7  objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27),
#
# NameError: name 'XGBClassifier' is not defined
